# %% [markdown]
# # Custom Evaluation Criteria
#
# In this notebook we define a evaluation criteria that is suitable for a multi-class multi-label classification problem, We do this to have an apple to apple comparison between different classifiers and modelling approach inorder to have unified standardized evaluation metric.
#
# We majorly will be doing the following :
#
#   1. Install & Import Packages
#   2. Define Document level 'Precision', 'Recall' and 'F1-measure'
#   3. Provide aggregated evaluation across documents along with illustrated examples
#   5. Save

# %% [markdown]
# # 1. Install & Import Packages

# %%
import os
import numpy as np
import pandas as pd
import pickle
import ast

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# # 2. Define Document level 'Precision', 'Recall' and 'F1-measure'
#
#
# We define precision for a document as follows:
# ${\displaystyle {\text{precision}}={\frac {|\{{\text{original labels}}\}\cap \{{\text{predicted labels}}\}|}{|\{{\text{predicted labels}}\}|}}}
# $
#
# Whereas recall for a document is:
# ${\displaystyle {\text{recall}}={\frac {|\{{\text{original labels}}\}\cap \{{\text{predicted labels}}\}|}{|\{{\text{original labels}}\}|}}}
# $
#
# And F measure derived from the above two values is:
#
# ${\displaystyle F=2\cdot {\frac {\mathrm {precision} \cdot \mathrm {recall} }{\mathrm {precision} +\mathrm {recall} }}}
# $
#
# The below function will calculate these metrics for each document, and at the end will give out average stats to measure overall standing

# %%
def document_evaluation_metrics(prd_grp,grp,metric="precision"):
    pred_group = prd_grp
    if 0 in pred_group: pred_group.remove(0)
    group = grp

    set_pred_group = set(pred_group)
    set_group = set(group)
    intrsct = set_group.intersection(set_pred_group)
    accuracy = len(intrsct) / float(len(set_pred_group) if len(set_pred_group)>1 else 1)
    recall = len(intrsct) / float(len(set_group) if len(set_group)>1 else 1)
    if metric == "precision":
      return accuracy
    elif metric == "recall":
      return recall
    elif metric == "f1_measure":
      if accuracy == 0 or recall == 0:
        return 0
      elif accuracy > 0 and recall >0 :
        f1_measure = 2*accuracy*recall/(float(accuracy + recall))
        return f1_measure
    
    return -1

def model_evaluation_stats(final_pred_df, model_name="default"):
  final_pred_df['doc_precision'] = final_pred_df.apply(lambda x: document_evaluation_metrics(x.predicted_labels, x.original_labels, "precision"), axis=1)
  final_pred_df['doc_recall'] = final_pred_df.apply(lambda x: document_evaluation_metrics(x.predicted_labels, x.original_labels, "recall"), axis=1)
  final_pred_df['doc_f1_measure'] = final_pred_df.apply(lambda x: document_evaluation_metrics(x.predicted_labels, x.original_labels, "f1_measure"), axis=1)
  
  avg_precision = final_pred_df['doc_precision'].mean()
  avg_recall = final_pred_df['doc_recall'].mean()
  avg_f1 = final_pred_df['doc_f1_measure'].mean()

  print('Avearge precision across documents is {}'.format(avg_precision))
  print('Avearge recall across documents is {}'.format(avg_recall))
  print('Avearge f1 measure across documents is {}'.format(avg_f1))

  row = { 'name': model_name,
          'avg_precision': avg_precision,
          'avg_recall':avg_recall,
          'avg_f1': avg_f1
       }
  
  record_path = ml_model+'record_metrics.csv'

  if os.path.exists(record_path) :
    record_df = pd.read_csv(record_path)
  else :
    record_df = pd.DataFrame(columns=['name','avg_precision','avg_recall','avg_f1'])

  record_df = record_df.append(row,ignore_index=True)
  record_df.to_csv(record_path,index=False)

  pickle.dump(final_pred_df, open(ml_model + model_name + ".pkl", 'wb'))
  # final_pred_df.to_csv(ml_model + 'SVM_Tag_predictions.txt',sep='\t',index=False)

# %% [markdown]
# # 3. Provide aggregated evaluation across documents along with illustrated examples

# %%
# Data read.
path = '/content/drive/My Drive/ICDMAI_Tutorial/notebook/'
data_path = path + 'training_data/70_30_split/'

# temporary output path
ml_model = path + 'ml_model/'

# %%
# Put list of the files that you create from testing in notebook : 6_inference_pipeline.ipynb
for data_filename in ['normalised_test_predicted_th_03','normalised_test_predicted_th_04','normalised_test_predicted_th_05',
                      'normalised_test_predicted_th_06','normalised_test_predicted_th_07','normalised_test_predicted_th_09'] :

  print("Processing : {}".format(data_filename))
  print()
  # data_filename =
  pred_df = pd.read_pickle(data_path + data_filename + '.pkl')

  model_evaluation_stats(pred_df,data_filename)
  print()
  print("========================================")

# %%
df = pd.read_pickle(ml_model  + '/normalised_test_predicted_th_09.pkl')

# %%
df.describe()
# Out:
#        doc_precision     doc_recall  doc_f1_measure
# count  157799.000000  157799.000000   157799.000000
# mean        0.038637       0.067447        0.045914
# std         0.141094       0.235249        0.159461
# min         0.000000       0.000000        0.000000
# 25%         0.000000       0.000000        0.000000
# 50%         0.000000       0.000000        0.000000
# 75%         0.000000       0.000000        0.000000
# max         1.000000       1.000000        1.000000

# %%
df = df.sort_values(by=['doc_f1_measure'],ascending=False)
df.head()
# Out:
#                                                      text  ... doc_f1_measure
# 122338  "TSQLT unit test - The data types text and tex...  ...            1.0
# 81538   TFS Build giving different results according t...  ...            1.0
# 58872   Conversion of long values into double in R. I'...  ...            1.0
# 73228   "Why does this Perl function appear to process...  ...            1.0
# 8666    Android Fragments Button Click Open new Window...  ...            1.0
#
# [5 rows x 6 columns]

# %%
df[df.doc_f1_measure>0.5].tail(50)
# Out:
#                                                      text  ... doc_f1_measure
# 155892  "jquery ui datepicker with tooltip - tooltip f...  ...       0.666667
# 156211  "accessing specific columns from another table...  ...       0.666667
# 21339   AWS Domain Name Email for SSL Cert. I create a...  ...       0.666667
# 9591    "Can a `ST`-like monad be executed purely (wit...  ...       0.666667
# 89732   PostgreSQL - Empty table. I have a table calle...  ...       0.666667
# 122812  "How to login with a user with role userAdmin ...  ...       0.666667
# 83679   How to invoke ModelB.create on ModelA.afterCre...  ...       0.666667
# 138205  "Regex to find numbers and letters. I would fi...  ...       0.666667
# 29742   "iText filling multi pages with same textfield...  ...       0.666667
# 21416   t\tHow do I remove a Visual Studio 2015 projec...  ...       0.666667
# 57845   How to create a checkbox grid using a has_many...  ...       0.666667
# 57843   Regex for specifying a date format. I have def...  ...       0.666667
# 89734   "Plot two columns in R from csv file. I have j...  ...       0.666667
# 29728   Why has Swift 1.2 broken inheritance of UIDyna...  ...       0.666667
# 122814  Upgrading gcc in dockerfile. I am trying to bu...  ...       0.666667
# 115675  C++ protected heritage. I have an abstract cla...  ...       0.666667
# 156236  C++ Removing elements from concurrent vectors....  ...       0.666667
# 76499   "C++ calculate sum of integers excluding multi...  ...       0.666667
# 57426   Azure IoT Hub change protocol from AMQP to HTT...  ...       0.666667
# 49026   how can i push to two repo at the same time. I...  ...       0.666667
# 98770   How do I re-create a deleted .gitmodule file?....  ...       0.666667
# 76382   "Using rmarkdown::render to set document heade...  ...       0.666667
# 112908  android 4.2.2 keyboard changes horizontal scro...  ...       0.666667
# 118176  "How to cast self to UnsafeMutablePointer type...  ...       0.666667
# 63742   Autodetect console output encoding in perl. I ...  ...       0.666667
# 149071  "Spark configuration ""spark.streaming.receive...  ...       0.666667
# 42024   ql\t"Perl PostgreSQL queries executes twice. I...  ...       0.571429
# 32085   erl\t"How to escape xml for use in perl multil...  ...       0.571429
# 97536   h\t"Multiline sed regex extraction issue: part...  ...       0.571429
# 45055   h\t"Inserting variable into bash script mongod...  ...       0.571429
# 69661   h\t"Access perl module within Bash script. I h...  ...       0.571429
# 36436   t\tUnable to push ruby on rails master project...  ...       0.571429
# 100967  d\tTests won't work with MongoMapper in Sinatr...  ...       0.571429
# 127912  sql\tpostgres database setup for dev staging p...  ...       0.571429
# 55259   r\t"R Merging 4 Strings into 1 String. I'm sea...  ...       0.571429
# 62424   ++\tReferenceTable overflow (jni android), arr...  ...       0.571429
# 53928   _r\tintegrating R with Rsruby. I was wondering...  ...       0.571429
# 50412   h\tjsvc (tomcat) does not daemonize properly w...  ...       0.571429
# 63900   t\t"Jenkins SCM Sync Configuration Plugin not ...  ...       0.571429
# 15997   sh\t"Annotating a C++ binary with bit of infor...  ...       0.571429
# 71621   r\t"In R Regex that ignores some punctuation a...  ...       0.571429
# 79229   ml\t"Parse the html code or use regex with jav...  ...       0.571429
# 32874   h\t"docker neo4j cannot connect to load csv fr...  ...       0.571429
# 105252  ql\t"Multiple Postgres SELECT processes(django...  ...       0.571429
# 24216   h\tRun Jenkins' Cygwin script as user. I have ...  ...       0.571429
# 145657  l\t"Parse guids out of a string in powershell....  ...       0.571429
# 73808   erl\t"Perl escaping argument for bash executio...  ...       0.571429
# 12656   +\tHooking into a C++ Program with Java. I hav...  ...       0.571429
# 103046  h\tReturning a part of the stdout of a bash co...  ...       0.571429
# 91536   t\t"swift rss feed parse extract href from con...  ...       0.571429
#
# [50 rows x 6 columns]
